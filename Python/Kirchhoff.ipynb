# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return (1+np.cos(np.arctan2(y, x)))/2/np.sqrt(x**2+y**2) - 1

def g(x, y):
    return 1/np.sqrt(X**2+Y**2)-1

x_vals = np.linspace(-1, 1, 1024)
y_vals = np.linspace(-1, 1, 1024)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f(X, Y)

plt.contour(X, Y, Z, levels=[0], colors='blue')
plt.contour(X, Y, g(X, Y), levels=[0], colors='r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('')
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
